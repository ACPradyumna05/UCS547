# %%
import numpy as np
import random

# %%
l1 = []
for i in range(1000000):
    l1.append(random.randint(1,10000))
l2 = np.zeros(1000000)
for i in range(1000000):
  l2[i]=random.randint(1,10000)

# %%
print(l1)

# %%
print(l2)
# Out:
# [2587. 2369. 4630. ... 5258. 8574. 3079.]

# %%
l3 = []
for i in range(1000000):
  l3.append(l1[i]*l1[i])

# %%
print(l3)

# %%
c = l2*l2

# %%
print(c)
# Out:
# [ 6692569.  5612161. 21436900. ... 27646564. 73513476.  9480241.]
